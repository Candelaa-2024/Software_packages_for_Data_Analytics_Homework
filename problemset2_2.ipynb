# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Drugs_Crime_Data.csv')
df
# Out:
#                 Offense Category Total\nOffenses  Drugs/\nNarcotics  \
# 0               Assault Offenses        2,706,772            72,312
# 1              Homicide Offenses           16,537               815
# 2     Human Trafficking Offenses            2,141               142
# 3           Kidnapping/Abduction           36,919             1,949
# 4                   Sex Offenses          177,043             6,061
# 5                          Arson           26,491               624
# 6                        Bribery              739                64
# 7   Burglary/Breaking & Entering          584,913             8,422
# 8         Counterfeiting/Forgery          107,047             1,941
# 9   Destruction/Damage/Vandalism        1,283,633            16,051
# 10                  Embezzlement           22,610               189
# 11           Extortion/Blackmail           12,270                50
# 12                Fraud Offenses          761,698             6,191
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Offense Category                  23 non-null     object
#  1   Total
# Offenses                    23 non-null     object
#  2   Drugs/
# Narcotics                  23 non-null     object
#  3   Percentage
# of Offense
# Category    23 non-null     object
#  4   Alcohol                           23 non-null     object
#  5   Percentage
# of Offense
# Category.1  23 non-null     object
# dtypes: object(6)
# memory usage: 1.2+ KB

# %%
df.isnull().sum()
# Out:
# Offense Category                      0
# Total\nOffenses                       0
# Drugs/\nNarcotics                     0
# Percentage\nof Offense\nCategory      0
# Alcohol                               0
# Percentage\nof Offense\nCategory.1    0
# dtype: int64

# %%
plt.figure(figsize=(8, 5))
df['Drugs/\nNarcotics'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Drug/Narcotics Offenses')
plt.xlabel('Drug/Narcotics')
plt.ylabel('Count')
plt.show()

# %%
fig = plt.figure(figsize=(50, 20))

plt.bar(df["Offense Category"],df["Alcohol"])
plt.show()
